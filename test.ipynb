# %%
import os
path = 'D:\\dataset\\konachan\\explicit\\'
for filename in os.listdir(path):
    if filename.endswith('.jpg'):
        png_filename = filename.replace('.jpg', '.png')
        png_filepath = os.path.join(path, png_filename)

        if os.path.exists(png_filepath):
            jpg_filepath = os.path.join(path, filename)
            os.remove(jpg_filepath)
            print('删除', filename)
# Out:
# 删除 361719.jpg
# 删除 361720.jpg
# 删除 361721.jpg
# 删除 361722.jpg
# 删除 361723.jpg
# 删除 361726.jpg
# 删除 361727.jpg
# 删除 361728.jpg
# 删除 361729.jpg
# 删除 361731.jpg
# 删除 361732.jpg
# 删除 361733.jpg
# 删除 361734.jpg
# 删除 361735.jpg
# 删除 361736.jpg
# 删除 361737.jpg
# 删除 361738.jpg
# 删除 361739.jpg
# 删除 361740.jpg
# 删除 361741.jpg
# 删除 361743.jpg
# 删除 361744.jpg
# 删除 361745.jpg
# 删除 361746.jpg
# 删除 361748.jpg
# 删除 361749.jpg
# 删除 361750.jpg
# 删除 361751.jpg
# 删除 361753.jpg
# 删除 361757.jpg
# 删除 361759.jpg
# 删除 361762.jpg
# 删除 361763.jpg
# 删除 361765.jpg
# 删除 361766.jpg
# 删除 361767.jpg
# 删除 361768.jpg
# 删除 361769.jpg
# 删除 361770.jpg
# 删除 361771.jpg
# 删除 361772.jpg
# 删除 361773.jpg
# 删除 361781.jpg
# 删除 361786.jpg
# 删除 361787.jpg
# 删除 361788.jpg
# 删除 361790.jpg
# 删除 361791.jpg
# 删除 361792.jpg
# 删除 361793.jpg
# 删除 361794.jpg
# 删除 361795.jpg
# 删除 361796.jpg
# 删除 361797.jpg

# %%
url = 'https://konachan.com/post.json?page=' + str(page) 
req = requests.get(url, headers=headers, proxies=proxies).content

# %%
# req = json.loads(req)
# 要查找的id值
target_id = 361755

# 使用next函数和生成器表达式找到匹配的字典
matched_dict = next((d for d in req if d["id"] == target_id), None)

if matched_dict:
    print("匹配的字典:", matched_dict)
else:
    print("未找到匹配的字典")
# Out:
# 匹配的字典: {'id': 361755, 'tags': 'all_male animal_ears anus ass blonde_hair blush censored fang flat_chest foxgirl male navel original otoko_no_ko penis short_hair spread_legs tail yellow_eyes ziv_zivy', 'created_at': 1692948566, 'creator_id': 41748, 'author': 'FormX', 'change': 2272266, 'source': '', 'score': 3, 'md5': '4b766473f373a7b4dcb611e1ed48e13d', 'file_size': 8578573, 'file_url': 'https://konachan.com/image/4b766473f373a7b4dcb611e1ed48e13d/Konachan.com%20-%20361755%20all_male%20anus%20ass%20blonde_hair%20blush%20censored%20fang%20flat_chest%20foxgirl%20male%20navel%20original%20penis%20short_hair%20spread_legs%20tail%20yellow_eyes%20ziv_zivy.png', 'is_shown_in_index': True, 'preview_url': 'https://konachan.com/data/preview/4b/76/4b766473f373a7b4dcb611e1ed48e13d.jpg', 'preview_width': 150, 'preview_height': 106, 'actual_preview_width': 300, 'actual_preview_height': 212, 'sample_url': 'https://konachan.com/sample/4b766473f373a7b4dcb611e1ed48e13d/Konachan.com%20-%20361755%20sample.jpg', 'sample_width': 1500, 'sample_height': 1061, 'sample_file_size': 734062, 'jpeg_url': 'https://konachan.com/jpeg/4b766473f373a7b4dcb611e1ed48e13d/Konachan.com%20-%20361755%20all_male%20anus%20ass%20blonde_hair%20blush%20censored%20fang%20flat_chest%20foxgirl%20male%20navel%20original%20penis%20short_hair%20spread_legs%20tail%20yellow_eyes%20ziv_zivy.jpg', 'jpeg_width': 4093, 'jpeg_height': 2894, 'jpeg_file_size': 1368460, 'rating': 'e', 'has_children': False, 'parent_id': None, 'status': 'active', 'width': 4093, 'height': 2894, 'is_held': False, 'frames_pending_string': '', 'frames_pending': [], 'frames_string': '', 'frames': []}

# %%
# 爬取konachan网站的图片
import os
import requests
import json
import time
from fake_useragent import UserAgent

# 生成随机的User-Agent，模仿人类操作请求
ua = UserAgent()
user_agent = ua.random

headers = {"User-Agent": user_agent}

# print(headers)

# 代理, 视自己使用的软件情况而定
proxies = {
    'http': 'http://127.0.0.1:33210',
    'https': 'http://127.0.0.1:33210',
    'all': 'socks5://127.0.0.1:33211'
}

# 下载图片
# tags = 'rating:safe+order:score'
safe_mode = True # 是否开启安全模式
tags = 'rating:safe' # 防止爬取到R18图片，要添加其他tag请在后面加上+号，例如 'rating:safe+girl'
pages_num = 1 # 爬取的页数

proxies_on = False # 是否开启代理 (如果开启代理，需要在上面设置好代理的端口)  
if not proxies_on:
    proxies = None

# 保存路径
if safe_mode:
    if os.name == 'nt':
        save_path = 'D:\\dataset\\konachan\\'
    elif os.name == 'posix':
        save_path = '~/dataset/konachan/'
else:
    if os.name == 'nt':
        save_path = 'D:\\dataset\\konachan\\explicit\\'
    elif os.name == 'posix':
        save_path = '~/dataset/konachan/explicit/'


if not os.path.exists(save_path):
    os.makedirs(save_path)

# .net 和 .com 的区别是：.net 一页只有9张图片，.com 一页有21张图片
# 没梯子只能上.net
# print(proxies)
print('Safe mode: ', safe_mode)
print('代理：', proxies_on)
print('保存路径：', save_path)
print('开始爬取...')

for page in range(1, pages_num + 1):
    while True:
        if safe_mode:
            if proxies_on:
                url = 'https://konachan.com/post.json?tags={}&page={}'.format(tags, page)
            else:
                url = 'https://konachan.net/post.json?tags={}&page={}'.format(tags, page)
        else:
            if proxies_on:
                url = 'https://konachan.com/post.json?page={}'.format(page)
            else:
                url = 'https://konachan.net/post.json?page={}'.format(page)
        try:
            post_req = requests.get(url, headers=headers, proxies=proxies)
            post = json.loads(post_req.content)
            # print(post)
            for i in range(len(post)):
                img_url = post[i]['file_url']
                img_name = post[i]['id']
                img_suffix = os.path.splitext(img_url)[1]
                if os.path.exists(save_path + str(img_name) + img_suffix):
                    print('第{}页第{}张图片已存在'.format(page, i + 1))
                    continue
                else:
                    time.sleep(0.1) # 防止爬取过快被封IP
                    img_req = requests.get(img_url, headers=headers, proxies=proxies)
                    img = img_req.content
                    with open(save_path + str(img_name) + img_suffix, 'wb') as f:
                        f.write(img)
                        print('第{}页第{}张图片下载完成'.format(page, i + 1), f'图片id: {img_name}{img_suffix}')

            print('第{}页爬取完成'.format(page))
            break
        except Exception as e:
            print(e)
            # 继续从失败处开始爬取
            print('第{}页爬取失败，正在重新爬取...'.format(page))
            continue
# Out:
# Safe mode:  True
# 代理： False
# 保存路径： D:\dataset\konachan\
# 开始爬取...
# 第1页第1张图片已存在
# 第1页第2张图片已存在
# 第1页第3张图片已存在
# 第1页第4张图片已存在
# 第1页第5张图片已存在
# 第1页第6张图片已存在
# 第1页第7张图片已存在
# 第1页第8张图片已存在
# 第1页第9张图片已存在
# 第1页第10张图片已存在
# 第1页第11张图片已存在
# 第1页第12张图片已存在
# 第1页第13张图片已存在
# 第1页第14张图片已存在
# 第1页第15张图片已存在
# 第1页第16张图片已存在
# 第1页第17张图片已存在
# 第1页第18张图片已存在
# 第1页第19张图片已存在
# 第1页第20张图片已存在
# 第1页第21张图片已存在
# 第1页爬取完成

# %%
# Out:
# -1 0 1 2 3 4 5 6 7 8
